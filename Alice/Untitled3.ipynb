# %%
from matplotlib import pyplot as plt
import seaborn as sns

import pickle
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix
from scipy.sparse import hstack
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression

# %%
times = ['time%s' % i for i in range(1, 11)]

train_df = pd.read_csv('train_sessions.csv',
                       index_col='session_id', parse_dates=times)

# %%
train_df['year'] = train_df['time1'].apply(lambda ts : ts.year)

# %%
train_df['month'] = train_df['time1'].apply(lambda ts : ts.month)

# %%
train_df['day'] = train_df['time1'].apply(lambda ts : ts.day)

# %%
train_df['dow'] = train_df['time1'].apply(lambda ts : ts.date().weekday())

# %%
train_df['hour'] = train_df['time1'].apply(lambda ts : ts.hour)
train_df['sesslen'] = (train_df[times].max(axis = 1) - df[times].min(axis = 1)).apply(lambda ts: round(ts.seconds / 60))

# %%
train_df['num_urls'] = train_df[times].count(axis = 1)

# %%
train_df['sub10'] = (train_df['num_urls'] < 10) * 1

# %%
df = train_df

# %%
sns.countplot(data = df, x = 'year')

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 3, 1)
sns.countplot(data = df, x = 'year')
plt.subplot(1, 3, 2)
plt.title('target = 1')
sns.countplot(data = df[df['target'] == 1], x = 'year')
plt.subplot(1, 3, 3)
sns.countplot(data = df[df['target'] == 0], x = 'year')

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.title('target = 1')
sns.countplot(data = df[df['target'] == 1], x = 'hour')
plt.subplot(1, 2, 2)
plt.title('target = 0')
sns.countplot(data = df[df['target'] == 0], x = 'hour')

# %%
df.head()
# Out:
#             site1               time1  site2               time2    site3  \
# session_id
# 1             718 2014-02-20 10:02:45    NaN                 NaT      NaN
# 2             890 2014-02-22 11:19:50  941.0 2014-02-22 11:19:50   3847.0
# 3           14769 2013-12-16 16:40:17   39.0 2013-12-16 16:40:18  14768.0
# 4             782 2014-03-28 10:52:12  782.0 2014-03-28 10:52:42    782.0
# 5              22 2014-02-28 10:53:05  177.0 2014-02-28 10:55:22    175.0
#
#                          time3    site4               time4  site5  \
# session_id
# 1                          NaT      NaN                 NaT    NaN
# 2          2014-02-22 11:19:51    941.0 2014-02-22 11:19:51  942.0
# 3          2013-12-16 16:40:19  14769.0 2013-12-16 16:40:19   37.0
# 4          2014-03-28 10:53:12    782.0 2014-03-28 10:53:42  782.0
# 5          2014-02-28 10:55:22    178.0 2014-02-28 10:55:23  177.0
#
#                          time5  ...    site9               time9   site10  \
# session_id                      ...
# 1                          NaT  ...      NaN                 NaT      NaN
# 2          2014-02-22 11:19:51  ...   1516.0 2014-02-22 11:20:15   1518.0
# 3          2013-12-16 16:40:19  ...  14768.0 2013-12-16 16:40:22  14768.0
# 4          2014-03-28 10:54:12  ...    782.0 2014-03-28 10:56:12    782.0
# 5          2014-02-28 10:55:23  ...    177.0 2014-02-28 10:57:06    178.0
#
#                         time10  target  year  month day  dow hour
# session_id
# 1                          NaT       0  2014      2  20    3   10
# 2          2014-02-22 11:20:16       0  2014      2  22    5   11
# 3          2013-12-16 16:40:24       0  2013     12  16    0   16
# 4          2014-03-28 10:56:42       0  2014      3  28    4   10
# 5          2014-02-28 10:57:11       0  2014      2  28    4   10
#
# [5 rows x 26 columns]

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.title('target = 1')
sns.countplot(data = df[df['target'] == 1], x = 'month')
plt.subplot(1, 2, 2)
plt.title('target = 0')
sns.countplot(data = df[df['target'] == 0], x = 'month')

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.title('target = 1')
sns.countplot(data = df[df['target'] == 1], x = 'dow')
plt.subplot(1, 2, 2)
plt.title('target = 0')
sns.countplot(data = df[df['target'] == 0], x = 'dow')

# %%
# Out:
#             site1               time1  site2               time2    site3  \
# session_id
# 1             718 2014-02-20 10:02:45    NaN                 NaT      NaN
# 2             890 2014-02-22 11:19:50  941.0 2014-02-22 11:19:50   3847.0
# 3           14769 2013-12-16 16:40:17   39.0 2013-12-16 16:40:18  14768.0
# 4             782 2014-03-28 10:52:12  782.0 2014-03-28 10:52:42    782.0
# 5              22 2014-02-28 10:53:05  177.0 2014-02-28 10:55:22    175.0
#
#                          time3    site4               time4  site5  \
# session_id
# 1                          NaT      NaN                 NaT    NaN
# 2          2014-02-22 11:19:51    941.0 2014-02-22 11:19:51  942.0
# 3          2013-12-16 16:40:19  14769.0 2013-12-16 16:40:19   37.0
# 4          2014-03-28 10:53:12    782.0 2014-03-28 10:53:42  782.0
# 5          2014-02-28 10:55:22    178.0 2014-02-28 10:55:23  177.0
#
#                          time5  ...               time9   site10  \
# session_id                      ...
# 1                          NaT  ...                 NaT      NaN
# 2          2014-02-22 11:19:51  ... 2014-02-22 11:20:15   1518.0
# 3          2013-12-16 16:40:19  ... 2013-12-16 16:40:22  14768.0
# 4          2014-03-28 10:54:12  ... 2014-03-28 10:56:12    782.0
# 5          2014-02-28 10:55:23  ... 2014-02-28 10:57:06    178.0
#
#                         time10 target  year month  day dow  hour sesslen
# session_id
# 1                          NaT      0  2014     2   20   3    10       0
# 2          2014-02-22 11:20:16      0  2014     2   22   5    11       0
# 3          2013-12-16 16:40:24      0  2013    12   16   0    16       0
# 4          2014-03-28 10:56:42      0  2014     3   28   4    10       4
# 5          2014-02-28 10:57:11      0  2014     2   28   4    10       4
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.title('target = 1')
sns.countplot(data = df[df['sesslen'] == 1], x = 'dow')
plt.subplot(1, 2, 2)
plt.title('target = 0')
sns.countplot(data = df[df['sesslen'] == 0], x = 'dow')

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.title('target = 1')
sns.countplot(data = df[df['target'] == 1], x = 'num_urls')
plt.subplot(1, 2, 2)
plt.title('target = 0')
sns.countplot(data = df[df['target'] == 0], x = 'num_urls')

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.title('target = 1')
sns.countplot(data = df[df['target'] == 1], x = 'sub10')
plt.subplot(1, 2, 2)
plt.title('target = 0')
sns.countplot(data = df[df['target'] == 0], x = 'sub10')
